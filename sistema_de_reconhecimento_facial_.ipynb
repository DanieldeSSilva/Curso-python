# %% [markdown]
# <a href="https://colab.research.google.com/github/DanieldeSSilva/Curso-python/blob/main/sistema_de_reconhecimento_facial_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow opencv-python pillow numpy matplotlib


# !pip install face_recognition

# Para trabalhar com YOLOv4
# Clonar o repositório do Darknet
# !git clone https://github.com/AlexeyAB/darknet.git

# Navegar até a pasta Darknet
# %cd darknet

# Compilar o Darknet com suporte para GPU e OpenCV
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make


# Outras bibliotecas úteis
import face_recognition
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Baixar os arquivos necessários para o YOLOv4.

# %%
# Baixar pesos e arquivos de configuração do YOLOv4
# !wget https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg
# !wget https://raw.githubusercontent.com/AlexeyAB/darknet/master/data/coco.names
# !wget https://pjreddie.com/media/files/yolov4.weights
# Baixar YOLOv4-tiny configurado para rostos
# !wget https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4-tiny.cfg
# !wget https://path_to_face_model/face.weights

# %% [markdown]
# Carregando o modelo YOLOv4 e definindo as configurações.

# %%
# Testar a detecção de objetos com YOLOv4
# !./darknet detect cfg/yolov4-tiny.cfg face.weights data/dog.jpg

# Exibir o resultado
from IPython.display import Image
Image('predictions.jpg')
